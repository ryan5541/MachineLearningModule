# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
songs = pd.read_csv('ml-03-data-processing-songs-dataset.csv')

# %%
songs.hist(figsize = [10,10])
# Out:
# array([[<AxesSubplot:title={'center':'Index'}>,
#         <AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Beats Per Minute (BPM)'}>],
#        [<AxesSubplot:title={'center':'Energy'}>,
#         <AxesSubplot:title={'center':'Danceability'}>,
#         <AxesSubplot:title={'center':'Loudness (dB)'}>],
#        [<AxesSubplot:title={'center':'Liveness'}>,
#         <AxesSubplot:title={'center':'Valence'}>,
#         <AxesSubplot:title={'center':'Acousticness'}>],
#        [<AxesSubplot:title={'center':'Speechiness'}>,
#         <AxesSubplot:title={'center':'Popularity'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#songs[songs['Year'] < 1000]['Year'].value_counts()
songs['Year'].where(songs['Year'] > 1000, 1992, inplace = True)

# %%
songs.Title.where(songs.Title.isna())
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1989    NaN
# 1990    NaN
# 1991    NaN
# 1992    NaN
# 1993    NaN
# Name: Title, Length: 1994, dtype: object

# %%
songs.Speechiness
# Out:
# 0        3.0
# 1        7.0
# 2       17.0
# 3        4.0
# 4        3.0
#         ...
# 1989     7.0
# 1990     6.0
# 1991     7.0
# 1992     4.0
# 1993     3.0
# Name: Speechiness, Length: 1994, dtype: float64
